# %%
# 필요한 라이브러리와 모듈을 불러옵니다.
from sklearn import datasets
import pandas as pd

# %%
# 붓꽃 품종 데이터 세트를 불러옵니다.
dataset = datasets.load_iris()

# 특성 데이터와 타깃을 준비합니다.
X, y = dataset['data'], dataset['target']

# %%
# 넘파이 배열 형태인 기존의 데이터를 판다스의 데이터 프레임으로 변환합니다.
column_names = ['sepal length', 'sepal width', 'petal length', 'petal width']
df = pd.DataFrame(X, columns=column_names)

# %%
# 판다스의 기능을 이용해 산점도 행렬을 그립니다.
pd.plotting.scatter_matrix(df, c=y)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f275998fcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f27599b8110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f275995ea10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2759915f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f27598d5550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2759889b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f275984d190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2759803650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2759803690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2759839d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f27597ae750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2759765cd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2759726290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f27596dc810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2759692d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2759656350>]],
#       dtype=object)
