# %%
# 데이터 세트를 다운받고 압축을 해제합니다.
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# !unzip cats_and_dogs_filtered.zip

# 맷플롯립 라이브러리와 OpenCV 라이브러리를 불러옵니다.
import matplotlib.pyplot as plt
import cv2
# Out:
# --2021-04-04 08:00:33--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.195.128, 64.233.191.128, 173.194.74.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip.2’
#
# cats_and_dogs_filte 100%[===================>]  65.43M   220MB/s    in 0.3s
#
# 2021-04-04 08:00:33 (220 MB/s) - ‘cats_and_dogs_filtered.zip.2’ saved [68606236/68606236]
#
# Archive:  cats_and_dogs_filtered.zip
# replace cats_and_dogs_filtered/vectorize.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# 흑백 이미지를 불러옵니다.
img_path = './cats_and_dogs_filtered/validation/dogs/dog.2000.jpg'
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# 이미지 크기를 가로 100, 세로 100으로 변경합니다.
img_resized = cv2.resize(img, (100, 100))

# 변경된 이미지 크기를 출력합니다.
print(img_resized.shape)

# 맷플롯립 라이브러리를 이용해 이미지를 출력합니다.
plt.imshow(img_resized, cmap='gray')
plt.show()
# Out:
# (100, 100)
